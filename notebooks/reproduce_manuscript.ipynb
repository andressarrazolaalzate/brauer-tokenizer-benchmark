# %% [markdown]
# # Reproduce the Brauer tokenizer manuscript
# This notebook uses the packaged implementation rather than duplicating the scientific code. Run it from a clone of this repository. The offline cells verify the mathematical core and Table 4; the final cell runs the five pinned Hugging Face tokenizers and verifies Tables 2–3.

# %%
# %pip install -e .

# %%
from brauer_tokenizer import verify_occurrence_closed_forms, entropy_asymptotic_coefficient
print('explicit checks:', verify_occurrence_closed_forms(12, 3))
for r in (1,2,3): print(r, entropy_asymptotic_coefficient(r))

# %%
# %run scripts/reproduce_table4.py

# %% [markdown]
# ## Full benchmark
# This step needs internet access once for the pinned tokenizer assets. No language-model weights are loaded.

# %%
# %pip install -e '.[benchmark]'
# !brauer-tokenizer-benchmark --output-dir results --verify-manuscript
